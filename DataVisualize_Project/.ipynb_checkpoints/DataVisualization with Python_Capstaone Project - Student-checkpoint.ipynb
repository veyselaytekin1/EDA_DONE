# %% [markdown]
# ![yaz%C4%B1.png](attachment:yaz%C4%B1.png)

# %% [markdown]
# <div class="alert alert-block alert-info alert">
#
# # <span style=" color:red">WELCOME!
#
# Welcome to "Bike Demand Visualization Project" which is the capstone project of Data Visualization Lessons . As you know recently, free or affordable access to bicycles has been provided for short-distance trips in an urban area as an alternative to motorized public transport or private vehicles. Thus, it is aimed to reduce traffic congestion, noise and air pollution.
#     Veysel
# </span>

# %% [markdown]
# <div class="alert alert-block alert-success ">
#
# ## <span style=" color:red">Determines
#
# Features
#
# - timestamp - timestamp field for grouping the data
# - cnt - the count of a new bike shares
# - t1 - real temperature in C
# - t2 - temperature in C “feels like”
# - hum - humidity in percentage
# - wind_speed - wind speed in km/h
# - weather_code - category of the weather
# - is_holiday - boolean field - 1 holiday / 0 non holiday
# - is_weekend - boolean field - 1 if the day is weekend
# - season - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.
#
# "weather_code" category description:
#
# - 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# - 2 = scattered clouds / few clouds
# - 3 = Broken clouds
# - 4 = Cloudy
# - 7 = Rain/ light Rain shower/ Light rain
# - 10 = rain with thunderstorm
# - 26 = snowfall
# - 94 = Freezing Fog
#
# Initially, the task of discovering data will be waiting for you as always. Recognize features, detect missing values, outliers etc. Review the data from various angles in different time breakdowns. For example, visualize the distribution of bike shares by day of the week. With this graph, you will be able to easily observe and make inferences how people's behavior changes daily. Likewise, you can make hourly, monthly, seasonally etc. analyzes. In addition, you can analyze correlation of variables with a heatmap.
#
# # <span style=" color:red">Tasks
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">1. Import Libraries
# </span>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">2. Read Dataset
# </span>

# %%
df = pd.read_csv('store_sharing.csv')
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">3. Check missing values and if there are any dublicate rows or not.
# </span>

# %%
df.isna().sum()
# Out:
# timestamp       0
# cnt             0
# t1              0
# t2              0
# hum             0
# wind_speed      0
# weather_code    0
# is_holiday      0
# is_weekend      0
# season          0
# dtype: int64

# %%
df[df.isna().any(axis = 1)]
#there are no NaN
# Out:
# Empty DataFrame
# Columns: [timestamp, cnt, t1, t2, hum, wind_speed, weather_code, is_holiday, is_weekend, season]
# Index: []

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %%
df.duplicated().unique()

#thre are no duplicated
# Out:
# array([False])

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">4. Plot the distribution of various discrete features on (Season, haliday, weekend and weathercode)
# </span>

# %%
df.head(2)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0

# %%
df['is_holiday'].value_counts()

#I wanted to know the data.It is not necessary for solution
# Out:
# 0.0    17030
# 1.0      384
# Name: is_holiday, dtype: int64

# %%
df['is_weekend'].value_counts()

#I wanted to know the data.It is not necessary for solution
# Out:
# 0.0    12444
# 1.0     4970
# Name: is_weekend, dtype: int64

# %%
df['season'].value_counts()

#I wanted to know the data.It is not necessary for solution
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: season, dtype: int64

# %%
df['weather_code'].value_counts()

#I wanted to know the data.It is not necessary for solution
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
print(df['t1'].unique().min())

print(df['t1'].unique().max())  #the temperature of wheater

#I wanted to know the data.It is not necessary for solution
# Out:
# -1.5
# 34.0

# %%
df['season'].unique()

#I wanted to know the data .It is not necessary for solution
# Out:
# array([3., 0., 1., 2.])

# %%
sns.countplot(df["weather_code"])

#I tried to plot same grapf, It is not necessary for solution
# Out:
# /Users/veyselaytekin/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='weather_code', ylabel='count'>

# %%
ax = sns.countplot(x="is_holiday", data=df)

#I tried to plot same grapf, It is not necessary for solution

# %%
fig, df_season = plt.subplots()
df_season = sns.countplot(x = "season", data = df); 

for p in df_season.patches:
    df_season.annotate(p.get_height(), (p.get_x() +0.3, p.get_height()));
    
#I tried to plot same grapf, It is not necessary for solution

# %%
fig, ax = plt.subplots(2,2 , figsize = (25,15))


a = sns.histplot(ax = ax[0][0] , data = df , x = "is_holiday" )
a.set_title("Holiday or Not ?") # Değişkene atayım set yap.

b = sns.histplot(data = df , x = "season" , ax = ax[0][1] , hue = "weather_code" , palette = "plasma" )
b.set_xlabel("SEASONS")

#c = sns.histplot(x = df["is_weekend"] , ax = ax[1][0] , hue = df["weather_code"] )
c = sns.histplot( x = df["is_weekend"] , ax = ax[1][0])
d = sns.histplot(x = df["weather_code"] , ax = ax[1][1] , bins = 30 , hue = df["season"] , palette= "plasma" );

# %%
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (10,10))



df_season = sns.countplot(x = "season", data = df , ax = ax[0, 0] )
for p in df_season.patches:  #I wanted to show the value on the colomns
    df_season.annotate(p.get_height(), (p.get_x() +0.3, p.get_height()));
    
    
    
df_holiday = sns.countplot(x = "is_holiday", data = df , ax = ax[0, 1])
df_holiday.set_title("Holiday or Not ?")
for p in df_holiday.patches: #I wanted to show the value on the colomns
    df_holiday.annotate(p.get_height(), (p.get_x() +0.3, p.get_height()));   
    
    
    
    
df_weekend = sns.countplot(x = 'is_weekend', data = df , ax = ax[1, 0] )
for p in df_weekend.patches: #I wanted to show the value on the colomns
    df_weekend.annotate(p.get_height(), (p.get_x() +0.3, p.get_height()));    
    
    
    
    
df_weather_code = sns.countplot(x = 'weather_code', data = df , ax = ax[1, 1] )
for p in df_weather_code.patches: #I wanted to show the value on the colomns
    df_weather_code.annotate(p.get_height(), (p.get_x() +0.1, p.get_height())); 
    
#I did assign the grapf to grapf to write clean code

# %% [markdown]
# # weather_code
# sns.countplot(x='weather_code',data=df)
#
# 1 = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity
# 2 = scattered clouds / few clouds
# 3 = Broken clouds
# 4 = Cloudy
# 7 = Rain/ light Rain shower/ Light rain
# 10 = rain with thunderstorm
# 26 = snowfall
# 94 = Freezing Fog

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">5. Look at the data type of each variable, transform timestamp in type, and set it as index.
# </span>

# %%
df.head(2)
# Out:
#              timestamp  cnt   t1   t2   hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0  93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5  93.0         5.0           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df['timestamp'] = df['timestamp'].astype('datetime64')

#I did change the type of column, so it is so easy to work with that
#for example, if I need for a column the month ,I can call the data with code 
#df['timestamp'].dt.month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %%
df.index = df['timestamp']

# %%
df.head()
# Out:
#                               timestamp  cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5
#
#                      weather_code  is_holiday  is_weekend  season
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">6. Make feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)
# </span>

# %%
from datetime import date, datetime, time
from babel.dates import format_date, format_datetime, format_time


df['day_of_the_week'] = df['timestamp'].apply(format_date, format='E', locale='de_DE')

# %%
df['day_of_the_month'] = df['timestamp'].dt.day

# %%
df['Hour'] =df['timestamp'].dt.hour

# %%
df['month'] =df['timestamp'].dt.month

# %%
df['year'] =df['timestamp'].dt.year

# %%
df
# Out:
#                               timestamp   cnt   t1   t2    hum  wind_speed  \
# timestamp
# 2015-01-04 00:00:00 2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0
# 2015-01-04 01:00:00 2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0
# 2015-01-04 02:00:00 2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0
# 2015-01-04 03:00:00 2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0
# 2015-01-04 04:00:00 2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5
# ...                                 ...   ...  ...  ...    ...         ...
# 2017-01-03 19:00:00 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0
# 2017-01-03 20:00:00 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0
# 2017-01-03 21:00:00 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0
# 2017-01-03 22:00:00 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0
# 2017-01-03 23:00:00 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0
#
#                      weather_code  is_holiday  is_weekend  season  \
# timestamp
# 2015-01-04 00:00:00           3.0         0.0         1.0     3.0
# 2015-01-04 01:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 02:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 03:00:00           1.0         0.0         1.0     3.0
# 2015-01-04 04:00:00           1.0         0.0         1.0     3.0
# ...                           ...         ...         ...     ...
# 2017-01-03 19:00:00           3.0         0.0         0.0     3.0
# 2017-01-03 20:00:00           4.0         0.0         0.0     3.0
# 2017-01-03 21:00:00           4.0         0.0         0.0     3.0
# 2017-01-03 22:00:00           4.0         0.0         0.0     3.0
# 2017-01-03 23:00:00           2.0         0.0         0.0     3.0
#
#                     day_of_the_week  day_of_the_month  Hour  month  year
# timestamp
# 2015-01-04 00:00:00             So.                 4     0      1  2015
# 2015-01-04 01:00:00             So.                 4     1      1  2015
# 2015-01-04 02:00:00             So.                 4     2      1  2015
# 2015-01-04 03:00:00             So.                 4     3      1  2015
# 2015-01-04 04:00:00             So.                 4     4      1  2015
# ...                             ...               ...   ...    ...   ...
# 2017-01-03 19:00:00             Di.                 3    19      1  2017
# 2017-01-03 20:00:00             Di.                 3    20      1  2017
# 2017-01-03 21:00:00             Di.                 3    21      1  2017
# 2017-01-03 22:00:00             Di.                 3    22      1  2017
# 2017-01-03 23:00:00             Di.                 3    23      1  2017
#
# [17414 rows x 15 columns]

# %% [markdown]
# ![Screenshot%202021-10-27%20164721.png](attachment:Screenshot%202021-10-27%20164721.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">7. Visualize the correlation with a heatmap
# </span>

# %%
plt.figure(figsize = (14,8))
df_heatmap = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True);
df_heatmap
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (14,8))
df_heatmap = sns.heatmap(df.corr(), annot = True);
df_heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">8. Visualize the correlation of the target variable and the other features with barplot
# </span>

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = df.corr()
df_heatmap_2 = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.1g')

# %%
#and the other features with barplot


fig, ax=plt.subplots()
ax= sns.barplot(data=df, x='day_of_the_week', y='weather_code');
for p in ax.patches:
    ax.annotate(str(round(p.get_height(),2)),(p.get_x()+0.6, p.get_height()));
    
    
#burda günlere göre havanin kodunun ortalma nerelerde gezdigini gösteriyor, zaten yukaridaki bir grafikten    
#havanin seasonlara göre cok büyük degisiklikler göstermedigini görmüstük

# %% [markdown]
# ![Screenshot%202021-10-27%20170237.png](attachment:Screenshot%202021-10-27%20170237.png)

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">9. Plot bike shares over time use lineplot.
# </span>

# %%
plt.figure(figsize=(12,6))

sns.lineplot(data=df, x='month' , hue='year', y='cnt',palette='viridis') #palette renklendirme komutu,koymasanda renkler veriyor aslinda

plt.legend(loc=(1.1,.5)) 
sns.set(style='darkgrid')

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">10. Plot bike shares by months and year_of_month (use lineplot, pointplot, barplot).
# </span>

# %%
plt.figure(figsize = (12, 6))
sns.pointplot(data = df, x = "month", y = "cnt", hue = "year", palette= "viridis")
plt.legend(loc = (1.1, .5))
plt.show()

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">11. Plot bike shares by hours on (holidays, weekend, season).
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 12. Plot bike shares by day of week.
#
# - You may want to see whether it is a holiday or not
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 13. Plot bike shares by day of month
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red"> 14. Plot bike shares by year
#
# - Plot bike shares on holidays by seasons
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">15. Visualize the distribution of bike shares by weekday/weekend with piechart and barplot
# </span>

# %% [markdown]
# <div class="alert alert-warning alert-info">
# <span style=" color:red">16. Plot the distribution of weather code by seasons
# </span>

# %% [markdown]
# <div class="alert alert-info alert-info ">
#
# # <span style=" color:red">Conclusions
#
#
#
#
# </span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <span style=" color:red">Thanks for Attending!..
#
#
# </span>

# %% [markdown]
# ![yaz%C4%B1.webp](attachment:yaz%C4%B1.webp)
